# %%
from datasets import load_dataset

dataset = load_dataset("Sp1786/multiclass-sentiment-analysis-dataset")
dataset = dataset['train']  # merge train/val/test for simplicity
dataset = dataset.train_test_split(test_size=0.2)

# %%
from datasets import load_dataset

dataset = load_dataset("Sp1786/multiclass-sentiment-analysis-dataset")
dataset = dataset['train']  # merge train/val/test for simplicity
dataset = dataset.train_test_split(test_size=0.2)

# %%
import pandas as pd

df_train = pd.DataFrame(dataset['train'])
df_test = pd.DataFrame(dataset['test'])

print("Train size:", len(df_train))
print("Test size:", len(df_test))
df_train.head()
# Out:
# Train size: 24985
# Test size: 6247
#       id                                               text  label sentiment
# 0  21000  Morning. Forgot my daily booth yesterday.. sho...      0  negative
# 1   6305  Getting ready to go study outside while having...      2  positive
# 2  17378  _Online When will the maintanance end? I would...      1   neutral
# 3   3489            I think Max (my cat) may really be gone      1   neutral
# 4  14072   www.youtube.com/watch?v=CyJvgnP9-vA sowwwwyy!...      0  negative

# %%
import re

def clean_text(text):
    if text is None:
        return ""
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"@\w+", "", text)
    text = re.sub(r"[^A-Za-z0-9\s]", "", text)
    return text.strip().lower()

df_train['text'] = df_train['text'].apply(clean_text)
df_test['text'] = df_test['text'].apply(clean_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=5000)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])

y_train = df_train['label']
y_test = df_test['label']

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(max_iter=200)
clf.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
from sklearn.metrics import classification_report

y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=["negative", "neutral", "positive"]))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.67      0.60      0.63      1808
#      neutral       0.60      0.67      0.63      2386
#     positive       0.75      0.71      0.73      2053
#
#     accuracy                           0.66      6247
#    macro avg       0.67      0.66      0.67      6247
# weighted avg       0.67      0.66      0.67      6247

# %%
import joblib

joblib.dump(clf, "../models/emoflagger_model.pkl")
joblib.dump(vectorizer, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']

# %%
import joblib

joblib.dump(clf, "../models/emoflagger_model.pkl")
joblib.dump(vectorizer, "../models/tfidf_vectorizer.pkl")
# Out:
# ['../models/tfidf_vectorizer.pkl']
